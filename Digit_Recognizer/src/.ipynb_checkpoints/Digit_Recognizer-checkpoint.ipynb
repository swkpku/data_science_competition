# %%
import tensorflow as tf
import pandas as pd

data_path = '../data/'

filename = data_path + 'train.csv'
#data, label = read_data(filename)
data = pd.read_csv(filename)

images = data.as_matrix(columns=[data.columns[1:]])
print('image shape: ', images.shape)

labels = data.as_matrix(columns=[data.columns[0]])
labels = labels.reshape(labels.shape[0])
print('label shape: ', labels.shape)

test_filename = data_path + 'test.csv'
test_data = pd.read_csv(test_filename)
test_images = test_data.as_matrix(columns=[test_data.columns[:]])
print('test image shape: ', test_images.shape)

num_data = images.shape[0]
data_dim = images.shape[1]
# Out:
# image shape:  (42000, 784)
# label shape:  (42000,)
# test image shape:  (28000, 784)

# %%
import numpy as np
# %matplotlib inline
import matplotlib.pyplot as plt
import matplotlib.cm as cm

def display_img(dataset, idx):
    image = dataset[idx]
    image_width = image_height = np.ceil(np.sqrt(data_dim)).astype(np.uint8)
    plt.axis('off')
    plt.imshow(image.reshape(image_width, image_height), cmap=cm.binary)
    plt.show()
    
display_img(images, 3)

# %%
num_train = 30000
num_val   = 12000

indicies = np.arange(num_data)
np.random.shuffle(indicies)
train_mask = indicies[range(num_train)]
val_mask = indicies[range(num_train, num_train + num_val)]

train_image = images[train_mask]
train_label = labels[train_mask]
val_image = images[val_mask]
val_label = labels[val_mask]

print('train image shape: ', train_image.shape)
print('train label shape: ', train_label.shape)
print('val image shape: ', val_image.shape)
print('val label shape: ', val_label.shape)
# Out:
# train image shape:  (30000, 784)
# train label shape:  (30000,)
# val image shape:  (12000, 784)
# val label shape:  (12000,)

# %%
num_epochs = 100
batch_size = 128
val_batch_size = 6000

num_test = test_images.shape[0]

def model(x):
    x = tf.reshape(x, [-1, 28, 28, 1])
    x = tf.layers.conv2d(x, filters=32, kernel_size=[3, 3], strides=[1, 1], padding='same', activation=tf.nn.relu)
    x = tf.layers.batch_normalization(x, training=True)
    x = tf.layers.conv2d(x, filters=32, kernel_size=[3, 3], strides=[1, 1], padding='same', activation=tf.nn.relu)
    x = tf.layers.batch_normalization(x, training=True)
    x = tf.layers.conv2d(x, filters=32, kernel_size=[3, 3], strides=[1, 1], padding='same', activation=tf.nn.relu)
    x = tf.layers.batch_normalization(x, training=True)
    x = tf.layers.max_pooling2d(x, pool_size=[2, 2], strides=[2, 2])
    x = tf.layers.conv2d(x, filters=64, kernel_size=[3, 3], strides=[1, 1], padding='same', activation=tf.nn.relu)
    x = tf.layers.batch_normalization(x, training=True)
    x = tf.layers.conv2d(x, filters=64, kernel_size=[3, 3], strides=[1, 1], padding='same', activation=tf.nn.relu)
    x = tf.layers.batch_normalization(x, training=True)
    x = tf.layers.conv2d(x, filters=64, kernel_size=[3, 3], strides=[1, 1], padding='same', activation=tf.nn.relu)
    x = tf.layers.batch_normalization(x, training=True)
    x = tf.layers.max_pooling2d(x, pool_size=[2, 2], strides=[2, 2])
    x = tf.contrib.layers.flatten(x)
    x = tf.layers.dense(inputs=x, units=4*4*64, activation=tf.nn.relu)
    x = tf.layers.dense(inputs=x, units=4*4*64, activation=tf.nn.relu)
    logits = tf.layers.dense(x, 10)
    return logits

tf.reset_default_graph()
X = tf.placeholder(tf.float32, [None, 784])
y = tf.placeholder(tf.int64, [None])

logits = model(X)

loss = tf.reduce_mean(tf.losses.softmax_cross_entropy(tf.one_hot(y, 10), logits=logits))

train_step = tf.train.AdamOptimizer(5e-4).minimize(loss)

predictions = tf.equal(tf.argmax(logits, 1), y)
acc = tf.reduce_mean(tf.cast(predictions, tf.float32))

train_indicies = np.arange(num_train)
np.random.shuffle(train_indicies)

val_indicies = np.arange(num_val)
test_indicies = np.arange(num_test)

test_predictions = tf.argmax(logits, 1)

def run_model(sess, show_every):
    print('training:')
    for epoch in range(num_epochs):
        print('epoch %d:' % epoch)
        for iter_i in range(num_train//batch_size):  
            start_idx = (iter_i*batch_size)%num_train
            idx = train_indicies[start_idx:start_idx+batch_size]
            
            _loss, _acc, _ = sess.run([loss, acc, train_step], feed_dict={
                X: train_image[idx, :], y: train_label[idx]
            })
            if iter_i % show_every == 0:
                print('iter: %d, loss: %f, acc: %f' % (iter_i, _loss, _acc))

        #total_correct = []
        for iter_i in range(num_val//val_batch_size):
            start_idx = (iter_i * val_batch_size) % num_val
            idx = val_indicies[start_idx:start_idx+val_batch_size]
            val_acc = sess.run(acc, feed_dict={
                X:val_image[idx, :], y: val_label[idx]
            })
            #total_correct = total_correct + val_correct_predictions
            print('val set acc: %f'% val_acc)
    
    print('predicting:')
    total_test_predictions = []
    test_batch_size = 7000
    for test_iter in range(num_test//test_batch_size):
        start_test_idx = (test_iter * test_batch_size)%num_test
        test_idx = test_indicies[start_test_idx:start_test_idx+test_batch_size]
        _test_predictions = sess.run(test_predictions, feed_dict={X:test_images[test_idx, :]})
        total_test_predictions = np.concatenate((total_test_predictions,_test_predictions))
    return total_test_predictions

with tf.Session() as sess:
    sess.run(tf.global_variables_initializer())
    result = run_model(sess, show_every=100)
    
print('done!')
# Out:
# training:
# epoch 0:
# iter: 0, loss: 3.665767, acc: 0.054688
# iter: 100, loss: 0.100437, acc: 0.953125
# iter: 200, loss: 0.050528, acc: 0.976562
# val set acc: 0.983500
# val set acc: 0.979500
# epoch 1:
# iter: 0, loss: 0.022247, acc: 0.992188
# iter: 100, loss: 0.026740, acc: 0.992188
# iter: 200, loss: 0.015893, acc: 1.000000
# val set acc: 0.983500
# val set acc: 0.983333
# epoch 2:
# iter: 0, loss: 0.018037, acc: 0.992188
# iter: 100, loss: 0.003844, acc: 1.000000
# iter: 200, loss: 0.029446, acc: 0.992188
# val set acc: 0.989500
# val set acc: 0.987000
# epoch 3:
# iter: 0, loss: 0.002482, acc: 1.000000
# iter: 100, loss: 0.011930, acc: 0.992188
# iter: 200, loss: 0.003936, acc: 1.000000
# val set acc: 0.987667
# val set acc: 0.986167
# epoch 4:
# iter: 0, loss: 0.001322, acc: 1.000000
# iter: 100, loss: 0.010622, acc: 1.000000
# iter: 200, loss: 0.001354, acc: 1.000000
# val set acc: 0.988333
# val set acc: 0.989167
# epoch 5:
# iter: 0, loss: 0.015364, acc: 0.984375
# iter: 100, loss: 0.013874, acc: 0.992188
# iter: 200, loss: 0.000475, acc: 1.000000
# val set acc: 0.989167
# val set acc: 0.987000
# epoch 6:
# iter: 0, loss: 0.000644, acc: 1.000000
# iter: 100, loss: 0.005217, acc: 1.000000
# iter: 200, loss: 0.000329, acc: 1.000000
# val set acc: 0.987833
# val set acc: 0.987167
# epoch 7:
# iter: 0, loss: 0.000298, acc: 1.000000
# iter: 100, loss: 0.009533, acc: 0.992188
# iter: 200, loss: 0.032747, acc: 0.992188
# val set acc: 0.987833
# val set acc: 0.985333
# epoch 8:
# iter: 0, loss: 0.007287, acc: 0.992188
# iter: 100, loss: 0.021637, acc: 0.992188
# iter: 200, loss: 0.027469, acc: 0.992188
# val set acc: 0.987000
# val set acc: 0.985000
# epoch 9:
# iter: 0, loss: 0.027771, acc: 0.992188
# iter: 100, loss: 0.015675, acc: 0.992188
# iter: 200, loss: 0.002449, acc: 1.000000
# val set acc: 0.986667
# val set acc: 0.987000
# epoch 10:
# iter: 0, loss: 0.005540, acc: 1.000000
# iter: 100, loss: 0.004135, acc: 1.000000
# iter: 200, loss: 0.000358, acc: 1.000000
# val set acc: 0.987500
# val set acc: 0.989833
# epoch 11:
# iter: 0, loss: 0.007759, acc: 0.992188
# iter: 100, loss: 0.001054, acc: 1.000000
# iter: 200, loss: 0.020108, acc: 0.992188
# val set acc: 0.990167
# val set acc: 0.990000
# epoch 12:
# iter: 0, loss: 0.000109, acc: 1.000000
# iter: 100, loss: 0.000075, acc: 1.000000
# iter: 200, loss: 0.000892, acc: 1.000000
# val set acc: 0.990833
# val set acc: 0.990833
# epoch 13:
# iter: 0, loss: 0.000373, acc: 1.000000
# iter: 100, loss: 0.019735, acc: 0.992188
# iter: 200, loss: 0.010022, acc: 0.992188
# val set acc: 0.990833
# val set acc: 0.988500
# epoch 14:
# iter: 0, loss: 0.068414, acc: 0.992188
# iter: 100, loss: 0.016347, acc: 0.992188
# iter: 200, loss: 0.020206, acc: 0.992188
# val set acc: 0.988000
# val set acc: 0.986333
# epoch 15:
# iter: 0, loss: 0.025616, acc: 0.992188
# iter: 100, loss: 0.000006, acc: 1.000000
# iter: 200, loss: 0.011137, acc: 0.992188
# val set acc: 0.988333
# val set acc: 0.984833
# epoch 16:
# iter: 0, loss: 0.000326, acc: 1.000000
# iter: 100, loss: 0.000419, acc: 1.000000
# iter: 200, loss: 0.000431, acc: 1.000000
# val set acc: 0.990000
# val set acc: 0.988500
# epoch 17:
# iter: 0, loss: 0.000167, acc: 1.000000
# iter: 100, loss: 0.000092, acc: 1.000000
# iter: 200, loss: 0.002025, acc: 1.000000
# val set acc: 0.990167
# val set acc: 0.990167
# epoch 18:
# iter: 0, loss: 0.000417, acc: 1.000000
# iter: 100, loss: 0.003112, acc: 1.000000
# iter: 200, loss: 0.000066, acc: 1.000000
# val set acc: 0.987667
# val set acc: 0.988500
# epoch 19:
# iter: 0, loss: 0.000066, acc: 1.000000
# iter: 100, loss: 0.016086, acc: 0.992188
# iter: 200, loss: 0.000084, acc: 1.000000
# val set acc: 0.988833
# val set acc: 0.989833
# epoch 20:
# iter: 0, loss: 0.000100, acc: 1.000000
# iter: 100, loss: 0.000847, acc: 1.000000
# iter: 200, loss: 0.053576, acc: 0.992188
# val set acc: 0.989500
# val set acc: 0.990500
# epoch 21:
# iter: 0, loss: 0.001270, acc: 1.000000
# iter: 100, loss: 0.008397, acc: 0.992188
# iter: 200, loss: 0.000289, acc: 1.000000
# val set acc: 0.991333
# val set acc: 0.990333
# epoch 22:
# iter: 0, loss: 0.005657, acc: 0.992188
# iter: 100, loss: 0.000086, acc: 1.000000
# iter: 200, loss: 0.000638, acc: 1.000000
# val set acc: 0.990500
# val set acc: 0.988667
# epoch 23:
# iter: 0, loss: 0.000066, acc: 1.000000
# iter: 100, loss: 0.000538, acc: 1.000000
# iter: 200, loss: 0.008324, acc: 0.992188
# val set acc: 0.992167
# val set acc: 0.990500
# epoch 24:
# iter: 0, loss: 0.025737, acc: 0.992188
# iter: 100, loss: 0.012971, acc: 0.992188
# iter: 200, loss: 0.000073, acc: 1.000000
# val set acc: 0.991667
# val set acc: 0.990500
# epoch 25:
# iter: 0, loss: 0.000169, acc: 1.000000
# iter: 100, loss: 0.013119, acc: 0.992188
# iter: 200, loss: 0.000179, acc: 1.000000
# val set acc: 0.992667
# val set acc: 0.991167
# epoch 26:
# iter: 0, loss: 0.003412, acc: 1.000000
# iter: 100, loss: 0.001246, acc: 1.000000
# iter: 200, loss: 0.035465, acc: 0.992188
# val set acc: 0.991833
# val set acc: 0.988500
# epoch 27:
# iter: 0, loss: 0.000006, acc: 1.000000
# iter: 100, loss: 0.000252, acc: 1.000000
# iter: 200, loss: 0.000000, acc: 1.000000
# val set acc: 0.992333
# val set acc: 0.991500
# epoch 28:
# iter: 0, loss: 0.000870, acc: 1.000000
# iter: 100, loss: 0.000012, acc: 1.000000
# iter: 200, loss: 0.000002, acc: 1.000000
# val set acc: 0.988667
# val set acc: 0.986833
# epoch 29:
# iter: 0, loss: 0.006182, acc: 1.000000
# iter: 100, loss: 0.000078, acc: 1.000000
# iter: 200, loss: 0.085364, acc: 0.992188
# val set acc: 0.989667
# val set acc: 0.989000
# epoch 30:
# iter: 0, loss: 0.000051, acc: 1.000000
# iter: 100, loss: 0.000512, acc: 1.000000
# iter: 200, loss: 0.006299, acc: 0.992188
# val set acc: 0.990667
# val set acc: 0.989333
# epoch 31:
# iter: 0, loss: 0.000839, acc: 1.000000
# iter: 100, loss: 0.000046, acc: 1.000000
# iter: 200, loss: 0.000526, acc: 1.000000
# val set acc: 0.990333
# val set acc: 0.989500
# epoch 32:
# iter: 0, loss: 0.000010, acc: 1.000000
# iter: 100, loss: 0.000328, acc: 1.000000
# iter: 200, loss: 0.000069, acc: 1.000000
# val set acc: 0.992667
# val set acc: 0.992167
# epoch 33:
# iter: 0, loss: 0.000014, acc: 1.000000
# iter: 100, loss: 0.001444, acc: 1.000000
# iter: 200, loss: 0.038210, acc: 0.992188
# val set acc: 0.992500
# val set acc: 0.991333
# epoch 34:
# iter: 0, loss: 0.000089, acc: 1.000000
# iter: 100, loss: 0.000032, acc: 1.000000
# iter: 200, loss: 0.000003, acc: 1.000000
# val set acc: 0.992500
# val set acc: 0.991167
# epoch 35:
# iter: 0, loss: 0.034098, acc: 0.992188
# iter: 100, loss: 0.000083, acc: 1.000000
# iter: 200, loss: 0.001065, acc: 1.000000
# val set acc: 0.992667
# val set acc: 0.992667
# epoch 36:
# iter: 0, loss: 0.000000, acc: 1.000000
# iter: 100, loss: 0.000126, acc: 1.000000
# iter: 200, loss: 0.000081, acc: 1.000000
# val set acc: 0.993833
# val set acc: 0.993167
# epoch 37:
# iter: 0, loss: 0.000109, acc: 1.000000
# iter: 100, loss: 0.000408, acc: 1.000000
# iter: 200, loss: 0.000043, acc: 1.000000
# val set acc: 0.992500
# val set acc: 0.993000
# epoch 38:
# iter: 0, loss: 0.000001, acc: 1.000000
# iter: 100, loss: 0.005961, acc: 0.992188
# iter: 200, loss: 0.000141, acc: 1.000000
# val set acc: 0.992334
# val set acc: 0.992000
# epoch 39:
# iter: 0, loss: 0.000023, acc: 1.000000
# iter: 100, loss: 0.005214, acc: 1.000000
# iter: 200, loss: 0.000147, acc: 1.000000
# val set acc: 0.989833
# val set acc: 0.990000
# epoch 40:
# iter: 0, loss: 0.000009, acc: 1.000000
# iter: 100, loss: 0.001256, acc: 1.000000
# iter: 200, loss: 0.000001, acc: 1.000000
# val set acc: 0.990500
# val set acc: 0.989333
# epoch 41:
# iter: 0, loss: 0.000802, acc: 1.000000
# iter: 100, loss: 0.000148, acc: 1.000000
# iter: 200, loss: 0.000197, acc: 1.000000
# val set acc: 0.991833
# val set acc: 0.991000
# epoch 42:
# iter: 0, loss: 0.000000, acc: 1.000000
# iter: 100, loss: 0.000009, acc: 1.000000
# iter: 200, loss: 0.000153, acc: 1.000000
# val set acc: 0.991667
# val set acc: 0.990333
# epoch 43:
# iter: 0, loss: 0.000006, acc: 1.000000
# iter: 100, loss: 0.000381, acc: 1.000000
# iter: 200, loss: 0.000553, acc: 1.000000
# val set acc: 0.993500
# val set acc: 0.992000
# epoch 44:
# iter: 0, loss: 0.000000, acc: 1.000000
# iter: 100, loss: 0.000128, acc: 1.000000
# iter: 200, loss: 0.000021, acc: 1.000000
# val set acc: 0.990833
# val set acc: 0.991667
# epoch 45:
# iter: 0, loss: 0.000740, acc: 1.000000
# iter: 100, loss: 0.000000, acc: 1.000000
# iter: 200, loss: 0.000000, acc: 1.000000
# val set acc: 0.992500
# val set acc: 0.993000
# epoch 46:
# iter: 0, loss: 0.000000, acc: 1.000000
# iter: 100, loss: 0.002558, acc: 1.000000
# iter: 200, loss: 0.000003, acc: 1.000000
# val set acc: 0.991333
# val set acc: 0.991667
# epoch 47:
# iter: 0, loss: 0.000000, acc: 1.000000
# iter: 100, loss: 0.000001, acc: 1.000000
# iter: 200, loss: 0.000095, acc: 1.000000
# val set acc: 0.991500
# val set acc: 0.991000
# epoch 48:
# iter: 0, loss: 0.001694, acc: 1.000000
# iter: 100, loss: 0.000004, acc: 1.000000
# iter: 200, loss: 0.000007, acc: 1.000000
# val set acc: 0.994167
# val set acc: 0.992500
# epoch 49:
# iter: 0, loss: 0.002323, acc: 1.000000
# iter: 100, loss: 0.000001, acc: 1.000000
# iter: 200, loss: 0.000087, acc: 1.000000
# val set acc: 0.994000
# val set acc: 0.992500
# epoch 50:
# iter: 0, loss: 0.000000, acc: 1.000000
# iter: 100, loss: 0.000001, acc: 1.000000
# iter: 200, loss: 0.000009, acc: 1.000000
# val set acc: 0.994000
# val set acc: 0.992500
# epoch 51:
# iter: 0, loss: 0.000000, acc: 1.000000
# iter: 100, loss: 0.000001, acc: 1.000000
# iter: 200, loss: 0.000007, acc: 1.000000
# val set acc: 0.994000
# val set acc: 0.992500
# epoch 52:
# iter: 0, loss: 0.000000, acc: 1.000000
# iter: 100, loss: 0.000001, acc: 1.000000
# iter: 200, loss: 0.000006, acc: 1.000000
# val set acc: 0.994000
# val set acc: 0.992500
# epoch 53:
# iter: 0, loss: 0.000000, acc: 1.000000
# iter: 100, loss: 0.000001, acc: 1.000000
# iter: 200, loss: 0.000005, acc: 1.000000
# val set acc: 0.994167
# val set acc: 0.992667
# epoch 54:
# iter: 0, loss: 0.000000, acc: 1.000000
# iter: 100, loss: 0.000001, acc: 1.000000
# iter: 200, loss: 0.000004, acc: 1.000000
# val set acc: 0.994167
# val set acc: 0.992667
# epoch 55:
# iter: 0, loss: 0.000000, acc: 1.000000
# iter: 100, loss: 0.000000, acc: 1.000000
# iter: 200, loss: 0.000004, acc: 1.000000
# val set acc: 0.994000
# val set acc: 0.992667
# epoch 56:
# iter: 0, loss: 0.000000, acc: 1.000000
# iter: 100, loss: 0.000000, acc: 1.000000
# iter: 200, loss: 0.000003, acc: 1.000000
# val set acc: 0.994167
# val set acc: 0.992667
# epoch 57:
# iter: 0, loss: 0.000000, acc: 1.000000
# iter: 100, loss: 0.000000, acc: 1.000000
# iter: 200, loss: 0.000003, acc: 1.000000
# val set acc: 0.994167
# val set acc: 0.992667
# epoch 58:
# iter: 0, loss: 0.000000, acc: 1.000000
# iter: 100, loss: 0.000000, acc: 1.000000
# iter: 200, loss: 0.000003, acc: 1.000000
# val set acc: 0.994167
# val set acc: 0.992667
# epoch 59:
# iter: 0, loss: 0.000000, acc: 1.000000
# iter: 100, loss: 0.000000, acc: 1.000000
# iter: 200, loss: 0.000002, acc: 1.000000
# val set acc: 0.994167
# val set acc: 0.992667
# epoch 60:
# iter: 0, loss: 0.000000, acc: 1.000000
# iter: 100, loss: 0.000000, acc: 1.000000
# iter: 200, loss: 0.000002, acc: 1.000000
# val set acc: 0.994167
# val set acc: 0.992667
# epoch 61:
# iter: 0, loss: 0.000000, acc: 1.000000
# iter: 100, loss: 0.000000, acc: 1.000000
# iter: 200, loss: 0.000002, acc: 1.000000
# val set acc: 0.994167
# val set acc: 0.992667
# epoch 62:
# iter: 0, loss: 0.000000, acc: 1.000000
# iter: 100, loss: 0.000000, acc: 1.000000
# iter: 200, loss: 0.000002, acc: 1.000000
# val set acc: 0.994167
# val set acc: 0.992833
# epoch 63:
# iter: 0, loss: 0.000000, acc: 1.000000
# iter: 100, loss: 0.000000, acc: 1.000000
# iter: 200, loss: 0.000001, acc: 1.000000
# val set acc: 0.993833
# val set acc: 0.992833
# epoch 64:
# iter: 0, loss: 0.000000, acc: 1.000000
# iter: 100, loss: 0.000000, acc: 1.000000
# iter: 200, loss: 0.000001, acc: 1.000000
# val set acc: 0.994000
# val set acc: 0.992833
# epoch 65:
# iter: 0, loss: 0.000000, acc: 1.000000
# iter: 100, loss: 0.000000, acc: 1.000000
# iter: 200, loss: 0.000001, acc: 1.000000
# val set acc: 0.994000
# val set acc: 0.992833
# epoch 66:
# iter: 0, loss: 0.000000, acc: 1.000000
# iter: 100, loss: 0.000000, acc: 1.000000
# iter: 200, loss: 0.000001, acc: 1.000000
# val set acc: 0.994000
# val set acc: 0.992833
# epoch 67:
# iter: 0, loss: 0.000000, acc: 1.000000
# iter: 100, loss: 0.000000, acc: 1.000000
# iter: 200, loss: 0.000001, acc: 1.000000
# val set acc: 0.994000
# val set acc: 0.992833
# epoch 68:
# iter: 0, loss: 0.000000, acc: 1.000000
# iter: 100, loss: 0.000000, acc: 1.000000
# iter: 200, loss: 0.000001, acc: 1.000000
# val set acc: 0.994167
# val set acc: 0.992833
# epoch 69:
# iter: 0, loss: 0.000000, acc: 1.000000
# iter: 100, loss: 0.000000, acc: 1.000000
# iter: 200, loss: 0.000001, acc: 1.000000
# val set acc: 0.994167
# val set acc: 0.992667
# epoch 70:
# iter: 0, loss: 0.000000, acc: 1.000000
# iter: 100, loss: 0.000000, acc: 1.000000
# iter: 200, loss: 0.000001, acc: 1.000000
# val set acc: 0.994167
# val set acc: 0.992667
# epoch 71:
# iter: 0, loss: 0.000000, acc: 1.000000
# iter: 100, loss: 0.000000, acc: 1.000000
# iter: 200, loss: 0.000001, acc: 1.000000
# val set acc: 0.994167
# val set acc: 0.992667
# epoch 72:
# iter: 0, loss: 0.000000, acc: 1.000000
# iter: 100, loss: 0.000000, acc: 1.000000
# iter: 200, loss: 0.000001, acc: 1.000000
# val set acc: 0.994167
# val set acc: 0.992833
# epoch 73:
# iter: 0, loss: 0.000000, acc: 1.000000
# iter: 100, loss: 0.000000, acc: 1.000000
# iter: 200, loss: 0.000000, acc: 1.000000
# val set acc: 0.994333
# val set acc: 0.992833
# epoch 74:
# iter: 0, loss: 0.000000, acc: 1.000000
# iter: 100, loss: 0.000000, acc: 1.000000
# iter: 200, loss: 0.000000, acc: 1.000000
# val set acc: 0.994333
# val set acc: 0.992833
# epoch 75:
# iter: 0, loss: 0.000000, acc: 1.000000
# iter: 100, loss: 0.000000, acc: 1.000000
# iter: 200, loss: 0.000000, acc: 1.000000
# val set acc: 0.994333
# val set acc: 0.992833
# epoch 76:
# iter: 0, loss: 0.000000, acc: 1.000000
# iter: 100, loss: 0.000000, acc: 1.000000
# iter: 200, loss: 0.000000, acc: 1.000000
# val set acc: 0.994333
# val set acc: 0.992833
# epoch 77:
# iter: 0, loss: 0.000000, acc: 1.000000
# iter: 100, loss: 0.000000, acc: 1.000000
# iter: 200, loss: 0.000000, acc: 1.000000
# val set acc: 0.994333
# val set acc: 0.992833
# epoch 78:
# iter: 0, loss: 0.000000, acc: 1.000000
# iter: 100, loss: 0.000000, acc: 1.000000
# iter: 200, loss: 0.000000, acc: 1.000000
# val set acc: 0.994333
# val set acc: 0.993000
# epoch 79:
# iter: 0, loss: 0.000000, acc: 1.000000
# iter: 100, loss: 0.000000, acc: 1.000000
# iter: 200, loss: 0.000000, acc: 1.000000
# val set acc: 0.994333
# val set acc: 0.993167
# epoch 80:
# iter: 0, loss: 0.000000, acc: 1.000000
# iter: 100, loss: 0.000000, acc: 1.000000
# iter: 200, loss: 0.000000, acc: 1.000000
# val set acc: 0.994667
# val set acc: 0.993167
# epoch 81:
# iter: 0, loss: 0.000000, acc: 1.000000
# iter: 100, loss: 0.000000, acc: 1.000000
# iter: 200, loss: 0.000000, acc: 1.000000
# val set acc: 0.994500
# val set acc: 0.993167
# epoch 82:
# iter: 0, loss: 0.000000, acc: 1.000000
# iter: 100, loss: 0.000000, acc: 1.000000
# iter: 200, loss: 0.000000, acc: 1.000000
# val set acc: 0.994667
# val set acc: 0.993167
# epoch 83:
# iter: 0, loss: 0.000000, acc: 1.000000
# iter: 100, loss: 0.000000, acc: 1.000000
# iter: 200, loss: 0.000000, acc: 1.000000
# val set acc: 0.994500
# val set acc: 0.993167
# epoch 84:
# iter: 0, loss: 0.000000, acc: 1.000000
# iter: 100, loss: 0.000000, acc: 1.000000
# iter: 200, loss: 0.000000, acc: 1.000000
# val set acc: 0.994500
# val set acc: 0.993333
# epoch 85:
# iter: 0, loss: 0.000000, acc: 1.000000
# iter: 100, loss: 0.000000, acc: 1.000000
# iter: 200, loss: 0.000000, acc: 1.000000
# val set acc: 0.994500
# val set acc: 0.993333
# epoch 86:
# iter: 0, loss: 0.000000, acc: 1.000000
# iter: 100, loss: 0.000000, acc: 1.000000
# iter: 200, loss: 0.000000, acc: 1.000000
# val set acc: 0.994500
# val set acc: 0.993333
# epoch 87:
# iter: 0, loss: 0.000000, acc: 1.000000
# iter: 100, loss: 0.000000, acc: 1.000000
# iter: 200, loss: 0.000000, acc: 1.000000
# val set acc: 0.994500
# val set acc: 0.993333
# epoch 88:
# iter: 0, loss: 0.000000, acc: 1.000000
# iter: 100, loss: 0.000000, acc: 1.000000
# iter: 200, loss: 0.000000, acc: 1.000000
# val set acc: 0.994500
# val set acc: 0.993333
# epoch 89:
# iter: 0, loss: 0.000000, acc: 1.000000
# iter: 100, loss: 0.000000, acc: 1.000000
# iter: 200, loss: 0.000000, acc: 1.000000
# val set acc: 0.994500
# val set acc: 0.993333
# epoch 90:
# iter: 0, loss: 0.000000, acc: 1.000000
# iter: 100, loss: 0.000000, acc: 1.000000
# iter: 200, loss: 0.000000, acc: 1.000000
# val set acc: 0.994500
# val set acc: 0.993333
# epoch 91:
# iter: 0, loss: 0.000000, acc: 1.000000
# iter: 100, loss: 0.000000, acc: 1.000000
# iter: 200, loss: 0.000000, acc: 1.000000
# val set acc: 0.994500
# val set acc: 0.993333
# epoch 92:
# iter: 0, loss: 0.000000, acc: 1.000000
# iter: 100, loss: 0.000000, acc: 1.000000
# iter: 200, loss: 0.000000, acc: 1.000000
# val set acc: 0.994500
# val set acc: 0.993333
# epoch 93:
# iter: 0, loss: 0.000000, acc: 1.000000
# iter: 100, loss: 0.000000, acc: 1.000000
# iter: 200, loss: 0.000000, acc: 1.000000
# val set acc: 0.994500
# val set acc: 0.993333
# epoch 94:
# iter: 0, loss: 0.000000, acc: 1.000000
# iter: 100, loss: 0.000000, acc: 1.000000
# iter: 200, loss: 0.000000, acc: 1.000000
# val set acc: 0.994500
# val set acc: 0.993333
# epoch 95:
# iter: 0, loss: 0.000000, acc: 1.000000
# iter: 100, loss: 0.000000, acc: 1.000000
# iter: 200, loss: 0.000000, acc: 1.000000
# val set acc: 0.994500
# val set acc: 0.993333
# epoch 96:
# iter: 0, loss: 0.000000, acc: 1.000000
# iter: 100, loss: 0.000000, acc: 1.000000
# iter: 200, loss: 0.000000, acc: 1.000000
# val set acc: 0.994500
# val set acc: 0.993333
# epoch 97:
# iter: 0, loss: 0.000000, acc: 1.000000
# iter: 100, loss: 0.000000, acc: 1.000000
# iter: 200, loss: 0.000000, acc: 1.000000
# val set acc: 0.994500
# val set acc: 0.993333
# epoch 98:
# iter: 0, loss: 0.000000, acc: 1.000000
# iter: 100, loss: 0.000000, acc: 1.000000
# iter: 200, loss: 0.000000, acc: 1.000000
# val set acc: 0.994500
# val set acc: 0.993333
# epoch 99:
# iter: 0, loss: 0.000000, acc: 1.000000
# iter: 100, loss: 0.000000, acc: 1.000000
# iter: 200, loss: 0.000000, acc: 1.000000
# val set acc: 0.994667
# val set acc: 0.993333
# predicting:
# done!

# %%
import csv

with open('submission.csv', 'w', newline='') as csvfile:
    datawriter = csv.writer(csvfile, delimiter=',')
    datawriter.writerow(['ImageId', 'Label'])
    for i, predict_label in enumerate(result):
        datawriter.writerow([i+1, predict_label.astype(np.uint8)])

print('done!')
# Out:
# done!

# %%
for i in range(7000, 7010):
    display_img(test_images, i)
