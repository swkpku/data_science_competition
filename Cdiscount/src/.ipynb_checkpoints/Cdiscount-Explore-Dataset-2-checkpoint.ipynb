# %%
import os, sys, math, io
import numpy as np
import pandas as pd
import multiprocessing as mp
import bson
import struct

# %matplotlib inline
import matplotlib.pyplot as plt

import tensorflow as tf

from collections import defaultdict
from tqdm import *

data_dir = '/mnt/data/cdiscount/'

from subprocess import check_output
print(check_output(["ls", data_dir]).decode("utf8"))

# Any results you write to the current directory are saved as output.
# Out:
# category_names.csv
# sample_submission.csv
# test.bson
# train_block_0.bson
# train_block_10.bson
# train_block_11.bson
# train_block_12.bson
# train_block_13.bson
# train_block_14.bson
# train_block_15.bson
# train_block_16.bson
# train_block_17.bson
# train_block_18.bson
# train_block_19.bson
# train_block_1.bson
# train_block_20.bson
# train_block_21.bson
# train_block_22.bson
# train_block_23.bson
# train_block_24.bson
# train_block_2.bson
# train_block_3.bson
# train_block_4.bson
# train_block_5.bson
# train_block_6.bson
# train_block_7.bson
# train_block_8.bson
# train_block_9.bson
# train.bson
# train_example.bson

# %%
train_bson_path = os.path.join(data_dir, "train.bson")
num_train_products = 7069896

test_bson_path = os.path.join(data_dir, "test.bson")
num_test_products = 1768172

categories_path = os.path.join(data_dir, "category_names.csv")
categories_df = pd.read_csv(categories_path, index_col="category_id")

# Maps the category_id to an integer index. This is what we'll use to
# one-hot encode the labels.
categories_df["category_idx"] = pd.Series(range(len(categories_df)), index=categories_df.index)

#categories_df.to_csv("categories.csv")
categories_df.head()
# Out:
#                          category_level1     category_level2  \
# category_id
# 1000021794         ABONNEMENT / SERVICES      CARTE PREPAYEE
# 1000012764   AMENAGEMENT URBAIN - VOIRIE  AMENAGEMENT URBAIN
# 1000012776   AMENAGEMENT URBAIN - VOIRIE  AMENAGEMENT URBAIN
# 1000012768   AMENAGEMENT URBAIN - VOIRIE  AMENAGEMENT URBAIN
# 1000012755   AMENAGEMENT URBAIN - VOIRIE        SIGNALETIQUE
#
#                              category_level3  category_idx
# category_id
# 1000021794         CARTE PREPAYEE MULTIMEDIA             0
# 1000012764                       ABRI FUMEUR             1
# 1000012776             ABRI VELO - ABRI MOTO             2
# 1000012768                    FONTAINE A EAU             3
# 1000012755   PANNEAU D'INFORMATION EXTERIEUR             4

# %%
print('number of categories = %d' % len(categories_df["category_idx"]))
print('number of category_level1 = %d' % len(categories_df["category_level1"].unique()))
print('number of category_level2 = %d' % len(categories_df["category_level2"].unique()))
print('number of category_level3 = %d' % len(categories_df["category_level3"].unique()))
# Out:
# number of categories = 5270
# number of category_level1 = 49
# number of category_level2 = 483
# number of category_level3 = 5263

# %%
#print(categories_df["category_level1"].value_counts())

for category_level1 in categories_df["category_level1"].unique():
    print(category_level1)
    categories_level_df = categories_df.loc[categories_df["category_level1"] == category_level1]
    print(categories_level_df["category_level2"].value_counts())
# Out:
# ABONNEMENT / SERVICES
# 	CARTE PREPAYEE    1 Name: category_level2, dtype: int64
# AMENAGEMENT URBAIN - VOIRIE
# 	SIGNALISATION ROUTIERE    3 AMENAGEMENT URBAIN        3 VOIRIE
# 2 SIGNALETIQUE              1 Name: category_level2, dtype: int64
# ANIMALERIE
# 	VETEMENT - ACCESSOIRE                  18 HABITAT - COUCHAGE
# 18 MATERIEL DE TOILETTAGE                 13 ALIMENTATION
# 13 JOUET                                  12 HYGIENE LITIERE
# DEJECTIONS             12 ACCESSOIRE POUR REPAS                  11
# PRODUIT DE SOIN - HYGIENE              11 ATTACHE - SELLERIE
# 11 EDUCATION - ACTIVITE                    9 AMENAGEMENT TECHNIQUE DE
# L'HABITAT      8 SECURITE - PROTECTION                   7 TRANSPORT -
# DEPLACEMENT - PROMENADE     7 MATERNAGE - ELEVAGE
# 4 DECORATION DE L'HABITAT                 4 Name: category_level2,
# dtype: int64
# APICULTURE
# 	OUTILS DE L'APICULTEUR    1 Name: category_level2, dtype: int64
# ART DE LA TABLE - ARTICLES CULINAIRES
# 	USTENSILES DE CUISINE            44 SERVICE DE TABLE
# 43 CUISSON DES ALIMENTS             28 ACCESSOIRE DE CUISINE
# 26 USTENSILES PATISSERIE            23 SERVICE APERITIF - OENOLOGIE
# 20 DECOUPE DES ALIMENTS             14 CONSERVATION DES ALIMENTS
# 12 SERVICE PETIT DEJEUNER           10 VAISSELLE JETABLE
# 9 USTENSILES DE PESAGE - MESURE     5 REPAS NOMADE
# 3 Name: category_level2, dtype: int64
# ARTICLES POUR FUMEUR
# 	CIGARETTE ELECTRONIQUE    14 CIGARETTE                 11 CHICHA -
# NARGUILE         10 PIPE                       5 CIGARE
# 4 VAPORISATEUR               4 Name: category_level2, dtype: int64
# AUTO - MOTO
# 	PIECES                                       187 OUTILLAGE
# 68 CONFORT CONDUCTEUR ET PASSAGER                45 NETTOYAGE -
# LIQUIDES ENTRETIEN                29 PORTAGE - REMORQUAGE
# 27 AIDE A LA CONDUITE - SECURITE                 23 EQUIPEMENT PILOTE
# 20 HABITATION MOBILE - AMENAGEMENT INTERIEUR     14 VEHICULE
# 12 BAGAGERIE AUTO-MOTO                            9 PNEUS
# 6 Name: category_level2, dtype: int64
# BAGAGERIE
# 	ACCESSOIRES BAGAGE     22 MAROQUINERIE           12 PETITE
# MAROQUINERIE    11 BUSINESS                8 BAGAGES                 4
# Name: category_level2, dtype: int64
# BATEAU MOTEUR - VOILIER
# 	PIECE MOTEUR DE BATEAU - PIECE MOTEUR DE HORS BORD    15 ACCASTILLAGE
# 13 ENTRETIEN                                             12
# ELECTRICITE                                            9 NAVIGATION -
# ELECTRONIQUE MARINE                       8 SECURITE
# 8 CONFORT A BORD                                         7 CORDAGE
# 6 MOUILLAGE                                              4 BATEAU A
# MOTEUR                                        2 MOTEUR DE BATEAU -
# MOTEUR DE HORS BORD                 2 ANNEXE - BARQUE
# 1 GREEMENT - VOILE                                       1 Name:
# category_level2, dtype: int64
# BIJOUX -  LUNETTES - MONTRES
# 	BIJOUX      26 LUNETTES    12 MONTRES     12 Name: category_level2,
# dtype: int64
# BRICOLAGE - OUTILLAGE - QUINCAILLERIE
# 	OUTIL A MAIN                                77 MACHINE OUTIL
# 49 ELECTRICITE - DOMOTIQUE                     43 SANITAIRE -
# PLOMBERIE                       38 SECURITE MAISON
# 38 CONSOMMABLE                                 36 QUINCAILLERIE
# 31 MENUISERIE - HUISSERIE - CLOTURE            28 OUTIL DE MESURE
# 18 GENIE THERMIQUE - CLIMATIQUE - CHAUFFAGE    18 MATERIAU GROS OEUVRE
# 17 MATERIEL CHANTIER                           13 PEINTURE -
# REVETEMENT MUR SOL PLAFOND       11 RANGEMENT OUTILS - PORTE-OUTILS
# 10 SECURITE - PROTECTION CHANTIER              10 PILE - LAMPE
# ELECTRIQUE                      3 CONTROLE D’ACCES
# 1 Name: category_level2, dtype: int64
# CHAUSSURES - ACCESSOIRES
# 	CHAUSSURES DE VILLE       13 ACCESSOIRES CHAUSSURES    11 BASKET -
# SPORTSWEAR        4 BOTTES - BOTTINES          3 CHAUSSURES DETENTE
# 2 Name: category_level2, dtype: int64
# COFFRET CADEAU BOX
# 	COFFRET THEMATIQUE    6 Name: category_level2, dtype: int64
# CONDITIONNEMENT
# 	EMBALLAGE ALIMENTAIRE     11 CALAGE - PROTECTION        9 CERCLAGE
# 6 EMBALLAGE PALETTISABLE     6 EMBALLAGE D'EXPEDITION     6 MATERIEL
# EMBALLAGE         3 PALETTISATION              1 Name:
# category_level2, dtype: int64
# DECO - LINGE - LUMINAIRE
# 	OBJET DE DECORATION - BIBELOT                          22 ARTICLES -
# DECORATION DE FETE                          20 LINGE DE LIT
# 19 LUMINAIRE D'INTERIEUR                                  18
# ACCESSOIRE SALLE DE BAIN                               16 DECORATION
# DE NOEL                                     14 LINGE DE TABLE -
# CUISINE                               13 RIDEAU - STORE - ACCESSOIRE
# 13 DECORATION MURALE - TABLEAU - CADRE PHOTO - STICKER    11
# ACCESSOIRE DE CHEMINEE                                 10 BOUGEOIR -
# PHOTOPHORE - BOUGIE - SENTEUR                9 VASE - COUPE - FLEUR
# 9 LINGE DE TOILETTE                                       6 COUSSIN ET
# HOUSSE                                       6 LINGE A USAGE UNIQUE
# 5 DECORATION DU SOL                                       5 HORLOGE -
# REVEIL                                        4 PORTE-MANTEAU - PATERE
# 2 LINGE DE PLAGE                                          2 MIROIR
# 2 Name: category_level2, dtype: int64
# DROGUERIE
# 	PRODUIT D'ENTRETIEN       27 MATERIEL D'ENTRETIEN      18 ENTRETIEN
# DU LINGE         9 COMBUSTIBLE                7 INSECTICIDE - RATICIDE
# 7 MATERIEL SOIN DU LINGE     6 PAPIERS                    2 PURETE DE
# L'AIR            2 COLLECTE DES DECHETS       2 PILES
# 1 Name: category_level2, dtype: int64
# DVD - BLU-RAY
# 	DVD        8 BLU-RAY    7 UMD        1 Name: category_level2, dtype:
# int64
# ELECTROMENAGER
# 	PETIT APPAREIL DE CUISSON        24 BEAUTE - BIEN-ETRE
# 24 PREPARATION CULINAIRE            20 ENTRETIEN DES SOLS - MAISON
# 17 PETIT DEJEUNER - CAFE            16 FABRICATION MAISON
# 15 COIFFURE                         12 SERVICE - CONSERVATION
# 12 GROS APPAREILS DE CUISSON        12 GROS APPAREILS FROID
# 10 REPASSAGE - COUTURE               7 ONGLERIE
# 7 SANTE - HYGIENE                   7 TRAITEMENT DE L AIR
# 7 GROS APPAREILS LAVAGE-SECHAGE     6 Name: category_level2, dtype:
# int64
# ELECTRONIQUE
# 	COMPOSANTS OPTOELECTRONIQUES    12 KIT ET MODULES                  11
# CAPTEURS                        11 CONNECTIQUE                     11
# COMPOSANTS ACTIFS               10 BOITIERS ET COFFRETS             8
# AUTOMATISME                      6 CABLES                           6
# PNEUMATIQUE - HYDRAULIQUE        5 COMPOSANTS PASSIFS               3
# Name: category_level2, dtype: int64
# EPICERIE
# 	DESSERTS - AIDE PATISSERIE                15 CONDIMENTS - SAUCES -
# AIDES CULINAIRES    14 CONFISERIE                                11
# CONSERVE DE LEGUME                         9 PATES - RIZ - CEREALES -
# LEGUMES SECS      7 ALIMENTATION INFANTILE                     7 PETIT
# DEJEUNER                             7 PRODUITS SALES APERITIF
# 5 CHARCUTERIE                                4 PLATS PREPARES
# 4 BISCUITS - PATISSERIE EMBALLEE             3 CONSERVE DE POISSON
# 3 COFFRET GASTRONOMIQUE                      3 TARTINAGE SUCRE
# 3 DIETETIQUE MINCEUR                         3 CONSERVE DE VIANDE
# 2 INSECTE COMESTIBLE                         1 Name: category_level2,
# dtype: int64
# FUNERAIRE
# 	INHUMATION - ORNEMENT    1 Name: category_level2, dtype: int64
# HYGIENE - BEAUTE - PARFUM
# 	CAPILLAIRE                   33 CORPS ET VISAGE              32
# MAQUILLAGE VISAGE - CORPS    26 ONGLERIE                     25 RASAGE
# - EPILATION           15 DENTAIRE                     11 HYGIENE BEBE
# 9 HYGIENE INTIME                8 PARFUM                        8 NAIL
# ART                      7 SOLAIRES                      4 HYGIENE NEZ
# ET OREILLE        4 CONTENANT VIDE                2 Name:
# category_level2, dtype: int64
# INFORMATIQUE
# 	COMPOSANT - PIECE DETACHEE                 31 CONNECTIQUE -
# ALIMENTATION                 14 PERIPHERIQUE PC
# 13 IMPRESSION - SCANNER                       13 STOCKAGE EXTERNE
# 12 CONSTRUCTION RESEAU                        11 CLAVIER - SOURIS -
# WEBCAM                  11 PROTECTION - PERSONNALISATION - SUPPORT
# 10 LOGICIELS                                   7 ORDINATEUR PORTABLE -
# NETBOOK               5 ORDINATEUR DE BUREAU                        4
# TABLETTE                                    4 ECRAN - ENCEINTE
# 2 Name: category_level2, dtype: int64
# INSTRUMENTS DE MUSIQUE
# 	INSTRUMENT - PERCUSSION           17 OUTIL - PIECE DETACHEE
# 15 MATERIEL DE JEU                   15 INSTRUMENT A VENT
# 9 INSTRUMENT A CORDES                6 CONFORT DU MUSICIEN
# 6 AMPLIFICATION ET EFFETS DU SON     5 INSTRUMENT - PIANO - CLAVIER
# 5 RANGEMENT                          4 ENTRETIEN DES INSTRUMENTS
# 2 Name: category_level2, dtype: int64
# JARDIN - PISCINE
# 	OUTILS D'EXTERIEUR - DE JARDIN       57 AMENAGEMENT EXTERIEUR - DU
# JARDIN    31 JARDINAGE                            28 PISCINE
# 21 CULTURE INDOOR                       17 LUMINAIRE D'EXTERIEUR
# 15 MEUBLES D'EXTERIEUR - DE JARDIN      13 ARROSAGE
# 12 CUISINE EXTERIEURE                   11 PISCINE - ENTRETIEN ET
# MESURE         9 HAMMAM - SAUNA - SPA                  8 DECORATION DU
# JARDIN                  5 VETEMENT DE JARDINAGE                 3
# Name: category_level2, dtype: int64
# JEUX - JOUETS
# 	JEUX DE RECRE - JEUX D'EXTERIEUR                       33 LOISIRS
# CREATIFS ET ACTIVITES MANUELLES                19 MULTIMEDIA ENFANT
# 19 JEUX DE SOCIETE                                        19
# IMAGINATION                                            15 MONDE
# MINIATURE                                        14 DRONE
# 14 JEUX SCIENTIFIQUES                                     12 JEUX DE
# CAFE - BAR                                     12 JONGLERIE
# 12 VEHICULE POUR ENFANT                                   11 JEUX
# D'EAU - JEUX DE PLAGE                             11 DEGUISEMENT -
# SPECTACLE                                11 JOUET D'IMITATION
# 9 CONSTRUCTION - MODELISME - MAQUETTE - MODELE REDUIT     9 POUPEE -
# PELUCHE                                        9 SPECIAL NOEL
# 1 Name: category_level2, dtype: int64
# JEUX VIDEO
# 	ACCESSOIRES CONSOLE - JEUX    28 JEUX VIDEO                    25
# CONSOLES                      20 JEUX DEMATERIALISES            1
# Name: category_level2, dtype: int64
# LIBRAIRIE
# 	CUISINE ET VINS                       13 LANGUES - DICTIONNAIRE
# 13 ARTS - CINEMA - MUSIQUE               12 INFORMATIQUE - INTERNET
# 11 DROIT                                  8 LITTERATURE
# 8 ENTREPRISE - MARKETING - FINANCE       8 LIVRE ENFANT - JEUNESSE
# 6 ENSEIGNEMENT                           6 ETUDES SUPERIEURES
# 6 TOURISME - VOYAGE                      6 SCOLAIRE - PARASCOLAIRE
# 6 SCIENCES TECHNIQUES                    6 SANTE - BIEN-ETRE
# 5 SCIENCES HUMAINES                      5 HISTOIRE - GEOGRAPHIE
# 5 BRICOLAGE - DECORATION - JARDINAGE     4 MEDECINE
# 4 ANIMAUX - NATURE                       4 LOISIRS - JEUX - SPORT
# 4 BANDE DESSINEE - MANGA - HUMOUR        4 POLITIQUE - ECONOMIE
# 3 SCIENCE-FICTION                        3 VIE PRATIQUE
# 3 ACTUALITE - POLITIQUE - SOCIETE        3 RELIGION- SPIRITUALITE
# 2 POLICIER - SUSPENSE                    2 LNPR - LIVRE NEUF A PRIX
# REDUIT        1 AUTRES LIVRES                          1 Name:
# category_level2, dtype: int64
# LITERIE
# 	ACCESSOIRES LITERIE    10 LIT                     9 ELEMENT DE LIT
# 5 LIT D'APPOINT           2 Name: category_level2, dtype: int64
# LOISIRS CREATIFS - BEAUX ARTS - PAPETERIE
# 	PAPIER - CAHIER - CARNET                                32 PETITES
# FOURNITURES                                     30 PEINTURE
# 30 MODELAGE - SCULPTURE                                    15
# CLASSEMENT - ARCHIVAGE                                  12 DESSIN -
# COLORIAGE                                      12 COLLECTION -
# PHILATELIE - CARTOPHILIE - NUMISMATIQUE    11 ECRITURE - CALLIGRAPHIE
# 11 PERLE - BIJOUX - BADGE                                  10 CARTERIE
# - CORRESPONDANCE                                9 TRACAGE - DECOUPAGE
# - COLLAGE                            8 SCRAPBOOKING
# 8 CREATION DE BOUGIE                                       7 EMBALLAGE
# CADEAU                                         5 RANGEMENT - TRANSPORT
# 4 ENCADREMENT                                              4 GRAVURE -
# PYROGRAVURE                                    3 EMBOSSAGE
# 3 MOSAIQUE                                                 3 PARFUM -
# SAVON                                           2 CUISINE CREATIVE
# 1 Name: category_level2, dtype: int64
# MANUTENTION
# 	ACCESSOIRES DE LEVAGE ET D'ARRIMAGE     9 TRANSPORT ET MANIPULATION
# DE CHARGES    6 APPAREILS DE LEVAGE                     4 Name:
# category_level2, dtype: int64
# MATERIEL DE BUREAU
# 	PETIT MATERIEL                 11 POUR LES PRESENTATIONS          9
# POUR L'AFFICHAGE                7 ORGANISATION DU BUREAU          6
# IDENTIFICATION DU PERSONNEL     4 MATERIEL PEDAGOGIQUE            3
# PROTECTION - ENTRETIEN          3 POUR LE COURRIER                2
# Name: category_level2, dtype: int64
# MATERIEL MEDICAL
# 	SOIN                                  15 MOBILIER MEDICAL
# 11 DIAGNOSTIC - EXAMEN                   10 INSTRUMENTATION
# 9 VETEMENTS MEDICAUX                     6 ACUPUNCTURE - MEDECINES
# PARALELLES     6 RESPIRATION - INTUBATION               5 ORL
# 4 KINESITHERAPIE - REEDUCATION           4 SECOURS - URGENCE
# 4 CARDIOLOGIE                            3 SOIN DENTAIRE
# 3 STERILISATION - DESINFECTION           3 PEDIATRIE - MATERNITE
# 3 MONITORING                             2 IMAGERIE - RADIOLOGIE
# 2 MATERIEL D'ETUDE ANATOMIQUE            2 OPTHALMOLOGIE
# 2 SIGNALISATION MEDICALE                 2 BIOLOGIE
# 2 ENDOSCOPIE                             2 PNEUMOLOGIE
# 1 UROLOGIE                               1 PEDICURIE - PODOLOGIE
# 1 GYNECOLOGIE                            1 Name: category_level2,
# dtype: int64
# MERCERIE
# 	ACCESSOIRES DE COUTURE     14 CONSOMMABLE COUTURE         8
# ACCESSOIRES DE FINITION     6 SUPPORT POUR COUTURE        3 RANGEMENT
# COUTURE           2 Name: category_level2, dtype: int64
# MEUBLE
# 	MEUBLE DE SEJOUR - ENTREE    20 MEUBLE DE CUISINE            16
# ACCESSOIRE DE MEUBLE         15 SIEGE - ASSISE               14 PETIT
# MEUBLE COMPLEMENT      13 MEUBLE DE CHAMBRE            10 MEUBLE DE
# SALLE DE BAIN      10 MEUBLE DE BUREAU              8 Name:
# category_level2, dtype: int64
# MUSIQUE
# 	CD        16 VINYLE    13 Name: category_level2, dtype: int64
# PARAPHARMACIE
# 	TRAITEMENTS LIBRE SERVICE - SOINS PATHOLOGIES    39 COMPLEMENTS
# ALIMENTAIRES - THE INFUSION SANTE    22 AIDE A LA MOBILITE
# 19 MATERIEL PARAMEDICAL                             15 SEXUALITE -
# GROSSESSE                             4 Name: category_level2, dtype:
# int64
# PHOTO - OPTIQUE
# 	ACCESSOIRES PHOTO - OPTIQUE         26 OBJECTIF - FLASH - ZOOM
# 15 STUDIO PHOTO - ECLAIRAGE            10 TREPIED - MONOPOD
# 8 PIECES DETACHEES PHOTO - OPTIQUE     8 JUMELLE - TELESCOPE - OPTIQUE
# 7 CAMESCOPE                            7 APPAREIL PHOTO NUMERIQUE
# COMPACT     5 CONSOMMABLES                         4 VISIONNAGE PHOTO
# 4 APPAREIL PHOTO NUMERIQUE REFLEX      2 APPAREIL PHOTO ARGENTIQUE
# 2 APPAREIL PHOTO NUMERIQUE BRIDGE      2 APPAREIL PHOTO NUMERIQUE
# HYBRIDE     2 CHAMBRE NOIRE                        1 Name:
# category_level2, dtype: int64
# POINT DE VENTE - COMMERCE - ADMINISTRATION
# 	MATERIEL D'ENCAISSEMENT             11 MOBILIER
# 9 SIGNALETIQUE - PRESENTATION          8 RAYONNAGE
# 6 SECURITE                             2 PROTECTION - ENTRETIEN -
# SUPPORT     1 ACCESSOIRES D'ADMINISTRATION         1 GESTION DU
# PERSONNEL                 1 FOURNITURE                           1
# EQUIPEMENT                           1 DISTRIBUTEUR AUTOMATIQUE
# 1 HYGIENE - SANITAIRE                  1 Name: category_level2, dtype:
# int64
# PRODUITS FRAIS
# 	POISSON                                     1 FLEURS COMESTIBLES OU
# HERBES AROMATIQUES    1 Name: category_level2, dtype: int64
# PRODUITS SURGELES
# 	GLACE    1 Name: category_level2, dtype: int64
# PUERICULTURE
# 	SOMMEIL BEBE                    25 ACCESSOIRES PROMENADE-VOYAGE    23
# REPAS BEBE                      22 SECURITE BEBE                   18
# TOILETTE BEBE                   15 MEUBLES BEBE                    15
# SOIN MAMAN                      13 SOIN BEBE                       11
# BAIN BEBE                       10 PROMENADE-VOYAGE                10
# MATERIEL EVEIL BEBE              8 JOUET PREMIER AGE                6
# COFFRET CADEAU BEBE              4 Name: category_level2, dtype: int64
# SONO - DJ
# 	ECLAIRAGE DE SCENE - EFFETS DE SCENE - MATERIEL DE SCENE    12
# AMPLIFICATION ET RESTITUTION DU SON                          6 EFFETS
# ET CONTROLE DU SON                                    6 HOME STUDIO
# 4 ENTRETIEN ET PIECES DETACHEES                                3
# CONSOMMABLES ET MATERIEL DE JEU                              3
# TRANSPORT - RANGEMENT                                        2
# ISOLATION ACOUSTIQUE                                         2 Name:
# category_level2, dtype: int64
# SPORT
# 	CYCLES                                                          61
# SPORT DE MONTAGNE                                               49
# TEXTILE TECHNIQUE                                               41
# FITNESS - MUSCULATION                                           41
# PECHE                                                           32
# SPORT D'EAU - GLISSE D'EAU                                      30
# CAMPING - CAMP DE BASE                                          25
# PROTECTION DU SPORTIF                                           21
# RUNNING - ATHLETISME                                            20
# PISCINE - PLONGEE - CHASSE SOUS-MARINE                          19
# GLISSE URBAINE                                                  19
# FOOTBALL                                                        17
# NUTRITION SPORTIVE                                              14
# SPORT DE COMBAT - ARTS MARTIAUX                                 14
# MULTISPORT                                                      14
# SPORT DE TIR - CHASSE                                           12
# GOLF                                                            12
# INSTRUMENT DE MESURE                                            11
# RUGBY                                                           11
# DANSE - GYMNASTIQUE - GR                                        10
# TENNIS                                                          10
# TENNIS DE TABLE - PING PONG                                      8
# HANDBALL                                                         8
# MATERIEL D'ENTRETIEN DE SPORT - PRODUIT D'ENTRETIEN DE SPORT     7
# BASKET-BALL                                                      6
# SPORT DE GLACE                                                   6
# BASEBALL                                                         5
# BADMINTON                                                        5
# MATERIEL D'ENTRAINEMENT                                          4
# SPORT EQUESTRE                                                   4
# VOLLEY-BALL                                                      4
# ELECTROSTIMULATION                                               3
# MATERIEL D'ARBITRAGE                                             2
# SPORT AERIEN                                                     2
# PETANQUE - BOWLING                                               2
# FOOTBALL AMERICAIN                                               2
# DISCIPLINE DE CIRQUE                                             1
# SPORT DE CHIEN                                                   1
# PELOTE BASQUE - PADEL - CHISTERA                                 1
# SQUASH                                                           1
# Name: category_level2, dtype: int64
# TATOUAGE - PIERCING
# 	BIJOU PIERCING                     12 DERMOGRAPHE - MACHINE A TATOUER
# 4 DESSIN - TRANSFERT                  3 ENCRE A TATOUAGE
# 2 MONTAGE DES AIGUILLES               1 AIGUILLE
# 1 PIERCING                            1 ENTRETIEN DERMOGRAPHE
# 1 Name: category_level2, dtype: int64
# TELEPHONIE - GPS
# 	ACCESSOIRE TELEPHONE                      43 ACCESSOIRE GPS
# 15 MONTRE INTELLIGENTE - MONTRE CONNECTEE     7 GPS
# 6 SMARTPHONE - MOBILE                        6 RADIOCOMMUNICATION
# 5 TELEPHONIE FIXE                            3 Name: category_level2,
# dtype: int64
# TENUE PROFESSIONNELLE
# 	VETEMENT PROFESSIONNEL         19 COIFFE PROFESSIONNELLE         10
# CHAUSSURES PROFESSIONNELLES     7 ACCESSOIRE PROFESSIONNEL        6
# Name: category_level2, dtype: int64
# TV - VIDEO - SON
# 	ACCESSOIRES TV - VIDEO - SON        20 LECTEUR MUSIQUE
# 13 AMPLIFICATEUR - ENCEINTES           10 PROTECTION - ENTRETIEN
# 10 ANTENNE - PARABOLE                   8 CAR AUDIO
# 7 VIDEOPROJECTION                      6 CASQUE - MICROPHONE -
# DICTAPHONE     5 LECTEUR - ENREGISTREUR VIDEO         5 HOME CINEMA
# 3 TELEVISEUR                           2 Name: category_level2, dtype:
# int64
# VIN - ALCOOL - LIQUIDES
# 	ALCOOL                              7 JUS - SODA -SIROP-BOISSON
# LACTEE    6 APERITIF                            4 VIN
# 4 BIERE ET CIDRE                      3 CHAMPAGNE - PETILLANT -
# MOUSSEUX    2 COFFRET CADEAU                      2 EAU
# 2 Name: category_level2, dtype: int64

# %%
def make_category_tables():
    cat2idx = {}
    idx2cat = {}
    for ir in categories_df.itertuples():
        category_id = ir[0]
        category_idx = ir[4]
        cat2idx[category_id] = category_idx
        idx2cat[category_idx] = category_id
    return cat2idx, idx2cat

cat2idx, idx2cat = make_category_tables()
cat2idx[1000012755], idx2cat[4]
# Out:
# (4, 1000012755)

# %%
def read_bson(bson_path, num_records, with_categories):
    rows = {}
    with open(bson_path, "rb") as f, tqdm(total=num_records) as pbar:
        offset = 0
        while True:
            item_length_bytes = f.read(4)
            if len(item_length_bytes) == 0:
                break

            length = struct.unpack("<i", item_length_bytes)[0]

            f.seek(offset)
            item_data = f.read(length)
            assert len(item_data) == length

            item = bson.BSON.decode(item_data)
            product_id = item["_id"]
            num_imgs = len(item["imgs"])

            row = [num_imgs, offset, length]
            if with_categories:
                row += [item["category_id"]]
            rows[product_id] = row

            offset += length
            f.seek(offset)
            pbar.update()

    columns = ["num_imgs", "offset", "length"]
    if with_categories:
        columns += ["category_id"]

    df = pd.DataFrame.from_dict(rows, orient="index")
    df.index.name = "product_id"
    df.columns = columns
    df.sort_index(inplace=True)
    return df

# %time train_offsets_df = read_bson(train_bson_path, num_records=num_train_products, with_categories=True)
# Out:
# 100%|██████████| 7069896/7069896 [02:16<00:00, 51833.55it/s]
# CPU times: user 1min 37s, sys: 29.4 s, total: 2min 7s
# Wall time: 2min 32s

# %%
train_offsets_df.head()
# Out:
#             num_imgs  offset  length  category_id
# product_id
# 0                  1       0    6979   1000010653
# 1                  1    6979    7318   1000010653
# 2                  1   14297    5455   1000004079
# 3                  1   19752    4580   1000004141
# 4                  1   24332    6346   1000015539

# %%
train_offsets_df.to_csv("train_offsets.csv")
# Out:
# 12371293

# %%
print('number of products = %d' % len(train_offsets_df))
print('number of catagories = %d' % len(train_offsets_df["category_id"].unique()))
print('number of images = %d' % train_offsets_df["num_imgs"].sum())
# Out:
# number of products = 7069896
# number of catagories = 5270
# number of images = 12371293

# %%
# %time test_offsets_df = read_bson(test_bson_path, num_records=num_test_products, with_categories=False)
# Out:
# 1768182it [00:29, 59293.44it/s]
# CPU times: user 21.5 s, sys: 5.22 s, total: 26.7 s
# Wall time: 32.7 s

# %%
test_offsets_df.head()
# Out:
#             num_imgs  offset  length
# product_id
# 10                 3       0   15826
# 14                 1   15826    5589
# 21                 1   21415    7544
# 24                 1   28959    4855
# 27                 1   33814    2921

# %%
test_offsets_df.to_csv("test_offsets.csv")

# %%
def make_val_set(df, split_percentage=0.2, drop_percentage=0.):
    # Find the product_ids for each category.
    category_dict = defaultdict(list)
    for ir in tqdm(df.itertuples()):
        category_dict[ir[4]].append(ir[0])

    train_list = []
    val_list = []
    with tqdm(total=len(df)) as pbar:
        for category_id, product_ids in category_dict.items():
            category_idx = cat2idx[category_id]

            # Randomly remove products to make the dataset smaller.
            keep_size = int(len(product_ids) * (1. - drop_percentage))
            if keep_size < len(product_ids):
                product_ids = np.random.choice(product_ids, keep_size, replace=False)

            # Randomly choose the products that become part of the validation set.
            val_size = int(len(product_ids) * split_percentage)
            if val_size > 0:
                val_ids = np.random.choice(product_ids, val_size, replace=False)
            else:
                val_ids = []

            # Create a new row for each image.
            for product_id in product_ids:
                row = [product_id, category_idx]
                for img_idx in range(df.loc[product_id, "num_imgs"]):
                    if product_id in val_ids:
                        val_list.append(row + [img_idx])
                    else:
                        train_list.append(row + [img_idx])
                pbar.update()
                
    columns = ["product_id", "category_idx", "img_idx"]
    train_df = pd.DataFrame(train_list, columns=columns)
    val_df = pd.DataFrame(val_list, columns=columns)   
    return train_df, val_df

train_images_df, val_images_df = make_val_set(train_offsets_df, split_percentage=0.2, drop_percentage=0.)
# Out:
# 7069896it [00:08, 864563.56it/s]
# 100%|██████████| 7069896/7069896 [05:03<00:00, 23282.91it/s]

# %%
train_images_df.head()
val_images_df.head()
print("Number of training images:", len(train_images_df))
print("Number of validation images:", len(val_images_df))
print("Total images:", len(train_images_df) + len(val_images_df))
# Out:
# Number of training images: 9900946
# Number of validation images: 2470347
# Total images: 12371293

# %%
len(train_images_df["category_idx"].unique()), len(val_images_df["category_idx"].unique())
# Out:
# (5270, 5270)

# %%
category_idx = 619
num_train = np.sum(train_images_df["category_idx"] == category_idx)
num_val = np.sum(val_images_df["category_idx"] == category_idx)
print('number of products in train set: %d' % num_train)
print('number of products in val set: %d' % num_val)
print('ratio = %f' % (num_val / num_train))
train_images_df.to_csv("train_images.csv")
val_images_df.to_csv("val_images.csv")
# Out:
# number of products in train set: 1766
# number of products in val set: 443
# ratio = 0.250849

# %%
def make_test_set(df):
    test_list = []
    for ir in tqdm(df.itertuples()):
        product_id = ir[0]
        num_imgs = ir[1]
        for img_idx in range(num_imgs):
            test_list.append([product_id, img_idx])

    columns = ["product_id", "img_idx"]
    test_df = pd.DataFrame(test_list, columns=columns)
    return test_df

# %%
test_images_df = make_test_set(test_offsets_df)
# Out:
# 1768182it [00:03, 537480.72it/s]

# %%
test_images_df.head()
# Out:
#    product_id  img_idx
# 0          10        0
# 1          10        1
# 2          10        2
# 3          14        0
# 4          21        0

# %%
print("Number of test images:", len(test_images_df))
# Out:
# Number of test images: 3095080

# %%
test_images_df.to_csv("test_images.csv")
